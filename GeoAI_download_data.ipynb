# %% [markdown]
# <a href="https://colab.research.google.com/github/stienheremans/geoai_testing/blob/testing_flanders/GeoAI_download_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download Data
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/download_data.ipynb)
#
# ## Install Package
# To use the `geoai-py` package, ensure it is installed in your environment. Uncomment the command below if needed.

# %%
# %pip install geoai-py

# %% [markdown]
# ## Import Libraries
# These modules allow downloading NAIP imagery and extracting building data statistics.

# %%
import leafmap
from geoai.download import (
    download_naip,
    download_overture_buildings,
    extract_building_stats,
)

# %% [markdown]
# ## Define Bounding Box
# Define the geographic extent (longitude and latitude) for data downloads.

# %%
m = leafmap.Map(center=[47.6526, -117.5923], zoom=16)
m.add_basemap("Esri.WorldImagery")
m
# Out:
# Map(center=[47.6526, -117.5923], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %% [markdown]
# Use the drawing tools to draw a rectangle on the map. If no rectangle is drawn, the default ROI will be used.

# %%
bbox = m.user_roi_bounds()
if bbox is None:
    bbox = (-117.6029, 47.65, -117.5936, 47.6563)

# %% [markdown]
# ## Download NAIP Imagery
# Fetch NAIP aerial imagery for the specified bounding box. The `max_items` parameter limits the number of downloaded files.

# %%
# Download NAIP imagery for the specified region
downloaded_files = download_naip(
    bbox=bbox,
    output_dir="naip_data",
    max_items=1,
    # year=2020,
)

print(f"Downloaded {len(downloaded_files)} files.")
# Out:
# Found 1 NAIP items.
# Downloading item 1/1: m_4711720_sw_11_060_20230701_20230911.tif
# m_4711720_sw_11_060_20230701_20230911.tif: 100%|██████████| 342M/342M [00:52<00:00, 6.78MiB/s]
# Successfully saved to naip_data/m_4711720_sw_11_060_20230701_20230911.tif
# Downloaded 1 files.

# %% [markdown]
# ## Download Building Data
# Retrieve building footprint data in GeoJSON format within the bounding box. The `verbose` flag provides detailed output.

# %%
# !pip install duckdb
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.4.2)

# %%
import importlib
import geoai.download
importlib.reload(geoai.download)
# Out:
# <module 'geoai.download' from '/usr/local/lib/python3.12/dist-packages/geoai/download.py'>

# %%
# Download buildings
data_file = download_overture_buildings(
    bbox=bbox,
    output="buildings.geojson",
)

# %%
data_file
# Out:
#                                        id  \
# 0    62c6baca-1785-4904-a2df-06794d604b4a
# 1    74ebf678-83fb-4539-ab4f-59ee34d7376d
# 2    528f6130-9c2d-4bf0-902b-aad384ab2320
# 3    82da1b5f-bcfc-4996-ac62-28efdd5ccdb2
# 4    5f000ade-d76f-4779-af08-212b5741121d
# ..                                    ...
# 377  6e49bc43-ff33-4ceb-ade8-1ebbe5eadee2
# 378  2533c88f-2e56-4e13-ae99-8a86cfc8ecb0
# 379  0dcc5190-3cbb-45d1-878d-28b65ed2c094
# 380  e62ffa10-a927-41c9-a371-25d9798a6ce1
# 381  b6d14779-1ff3-4323-8c9b-d8c327245ef0
#
#                                               geometry  \
# 0    POLYGON ((-117.59766 47.6512, -117.59765 47.65...
# 1    POLYGON ((-117.59603 47.65098, -117.59589 47.6...
# 2    POLYGON ((-117.5963 47.65121, -117.5962 47.651...
# 3    POLYGON ((-117.59604 47.65133, -117.59593 47.6...
# 4    POLYGON ((-117.59503 47.65124, -117.59509 47.6...
# ..                                                 ...
# 377  POLYGON ((-117.5995 47.65109, -117.5995 47.650...
# 378  POLYGON ((-117.60048 47.65102, -117.60048 47.6...
# 379  POLYGON ((-117.59834 47.65114, -117.59833 47.6...
# 380  POLYGON ((-117.59808 47.65114, -117.59808 47.6...
# 381  POLYGON ((-117.59766 47.65094, -117.59766 47.6...
#
#                                                   bbox  version  \
# 0    {'xmin': -117.59767150878906, 'xmax': -117.597...        3
# 1    {'xmin': -117.59616088867188, 'xmax': -117.595...        3
# 2    {'xmin': -117.59629821777344, 'xmax': -117.596...        3
# 3    {'xmin': -117.59605407714844, 'xmax': -117.595...        3
# 4    {'xmin': -117.59510040283203, 'xmax': -117.595...        1
# ..                                                 ...      ...
# 377  {'xmin': -117.5995101928711, 'xmax': -117.5994...        1
# 378  {'xmin': -117.6004867553711, 'xmax': -117.5997...        1
# 379  {'xmin': -117.59833526611328, 'xmax': -117.598...        3
# 380  {'xmin': -117.59808349609375, 'xmax': -117.597...        3
# 381  {'xmin': -117.59780883789062, 'xmax': -117.597...        3
#
#                                                sources  level      subtype  \
# 0    [{'property': '', 'dataset': 'Microsoft ML Bui...    NaN         None
# 1    [{'property': '', 'dataset': 'Microsoft ML Bui...    NaN         None
# 2    [{'property': '', 'dataset': 'Microsoft ML Bui...    NaN         None
# 3    [{'property': '', 'dataset': 'Microsoft ML Bui...    NaN         None
# 4    [{'property': '', 'dataset': 'OpenStreetMap', ...    NaN         None
# ..                                                 ...    ...          ...
# 377  [{'property': '', 'dataset': 'OpenStreetMap', ...    NaN         None
# 378  [{'property': '', 'dataset': 'OpenStreetMap', ...    NaN  residential
# 379  [{'property': '', 'dataset': 'Microsoft ML Bui...    NaN         None
# 380  [{'property': '', 'dataset': 'Microsoft ML Bui...    NaN         None
# 381  [{'property': '', 'dataset': 'Microsoft ML Bui...    NaN         None
#
#           class    height names  ...  min_height  min_floor  facade_color  \
# 0          None  4.170345  None  ...         NaN        NaN          None
# 1          None  5.264402  None  ...         NaN        NaN          None
# 2          None  4.116215  None  ...         NaN        NaN          None
# 3          None  4.835219  None  ...         NaN        NaN          None
# 4          None       NaN  None  ...         NaN        NaN          None
# ..          ...       ...   ...  ...         ...        ...           ...
# 377        None       NaN  None  ...         NaN        NaN          None
# 378  apartments       NaN  None  ...         NaN        NaN          None
# 379        None  2.323776  None  ...         NaN        NaN          None
# 380        None  2.462055  None  ...         NaN        NaN          None
# 381        None  5.063974  None  ...         NaN        NaN          None
#
#      facade_material  roof_material  roof_shape roof_direction  \
# 0               None           None        None            NaN
# 1               None           None        None            NaN
# 2               None           None        None            NaN
# 3               None           None        None            NaN
# 4               None           None        None            NaN
# ..               ...            ...         ...            ...
# 377             None           None        None            NaN
# 378             None           None        None            NaN
# 379             None           None        None            NaN
# 380             None           None        None            NaN
# 381             None           None        None            NaN
#
#     roof_orientation roof_color roof_height
# 0               None       None         NaN
# 1               None       None         NaN
# 2               None       None         NaN
# 3               None       None         NaN
# 4               None       None         NaN
# ..               ...        ...         ...
# 377             None       None         NaN
# 378             None       None         NaN
# 379             None       None         NaN
# 380             None       None         NaN
# 381             None       None         NaN
#
# [382 rows x 24 columns]

# %% [markdown]
# ## Extract Building Statistics
# If the building data file is successfully downloaded, extract and display relevant statistics such as area, count, and footprint details.

# %%
stats = extract_building_stats(data_file)
print(stats)
# Out:
# {'total_buildings': 382, 'has_height': 190, 'has_name': 0, 'bbox': [-117.6017984, 47.6509353, -117.5866178, 47.6550579]}

# %% [markdown]
# ## Visualize Datasets

# %%
m = leafmap.Map()
m.add_raster("naip_data/m_4711720_sw_11_060_20230701_20230911.tif", layer_name="NAIP")
m.add_geojson("buildings.geojson", layer_name="Buildings")
m
# Out:
# Map(center=[47.656247, -117.5938195], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_titl…

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/64475787-8ba1-4d12-8fe6-29fbb1dac2ed)
